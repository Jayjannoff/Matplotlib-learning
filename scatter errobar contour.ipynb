# %% [markdown]
# How to use sklearn datasets in matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()
features = iris.data.T
print(features)
plt.scatter(features[0],features[1],alpha=0.2,s=100*features[3],c=iris.target,cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1])
plt.colorbar()
plt.show()
# Out:
# [[5.1 4.9 4.7 4.6 5.  5.4 4.6 5.  4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#   5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.  5.  5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.
#   5.5 4.9 4.4 5.1 5.  4.5 4.4 5.  5.1 4.8 5.1 4.6 5.3 5.  7.  6.4 6.9 5.5
#   6.5 5.7 6.3 4.9 6.6 5.2 5.  5.9 6.  6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
#   6.3 6.1 6.4 6.6 6.8 6.7 6.  5.7 5.5 5.5 5.8 6.  5.4 6.  6.7 6.3 5.6 5.5
#   5.5 6.1 5.8 5.  5.6 5.7 5.7 6.2 5.1 5.7 6.3 5.8 7.1 6.3 6.5 7.6 4.9 7.3
#   6.7 7.2 6.5 6.4 6.8 5.7 5.8 6.4 6.5 7.7 7.7 6.  6.9 5.6 7.7 6.3 6.7 7.2
#   6.2 6.1 6.4 7.2 7.4 7.9 6.4 6.3 6.1 7.7 6.3 6.4 6.  6.9 6.7 6.9 5.8 6.8
#   6.7 6.7 6.3 6.5 6.2 5.9]
#  [3.5 3.  3.2 3.1 3.6 3.9 3.4 3.4 2.9 3.1 3.7 3.4 3.  3.  4.  4.4 3.9 3.5
#   3.8 3.8 3.4 3.7 3.6 3.3 3.4 3.  3.4 3.5 3.4 3.2 3.1 3.4 4.1 4.2 3.1 3.2
#   3.5 3.6 3.  3.4 3.5 2.3 3.2 3.5 3.8 3.  3.8 3.2 3.7 3.3 3.2 3.2 3.1 2.3
#   2.8 2.8 3.3 2.4 2.9 2.7 2.  3.  2.2 2.9 2.9 3.1 3.  2.7 2.2 2.5 3.2 2.8
# ...

# %% [markdown]
# And now how I will show you how I drawn this coloured scatters

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
color = rng.randn(100)
size = 1000*rng.randn(100)

# %%
plt.scatter(x,y,c=color,s=size,cmap='viridis',alpha=0.2)
plt.colorbar()
plt.show()

# %% [markdown]
# So new use of with matplotlib styles and errorbar

# %%
# %matplotlib inline
plt.style.use('seaborn-whitegrid')

# %%
x = np.linspace(0,10,50)
dy = 0.8
y = np.sin(x)+dy*np.random.randn(50)
plt.errorbar(x,y,yerr=dy,fmt='.k')
plt.show()

# %%
plt.errorbar(x,y,yerr=dy,fmt='o',color='black',ecolor='lightgrey',elinewidth=3,capsize=0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
x = np.linspace(0,10,100)
dy = 1
y = np.sin(x) + dy*np.random.randn(100)
plt.errorbar(x,y,yerr=dy,fmt='ok')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# Working with meshgrids and plt.contour

# %%
def f(x,y):
    return np.sin(x)**10+np.cos(10+x*y)*np.cos(x)
x = np.linspace(0,5,80)
y = np.linspace(0,5,90)
X,Y = np.meshgrid(x,y)
Z = f(X,Y)

# %%
plt.contour(X,Y,Z,colors='black')

# %%
plt.contour(X,Y,Z,cmap='RdGy')

# %%
plt.contourf(X,Y,Z,20,cmap='RdGy')
plt.colorbar();

# %%
plt.imshow(Z,extent = [0,5,0,5],origin='lower',cmap='RdGy')
plt.colorbar()
